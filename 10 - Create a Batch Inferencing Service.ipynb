# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.44.0 to work with mllearningworkspace

# %% [markdown]
# ## Train and register a model
#
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.891
# AUC: 0.8788322802129458
# /tmp/ipykernel_62299/2140859650.py:34: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   run.log('Accuracy', np.float(acc))
# /tmp/ipykernel_62299/2140859650.py:40: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   run.log('AUC', np.float(auc))
# Model trained and registered.

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# workspaceartifactstore - Default = False
# workspaceworkingdirectory - Default = False
# workspacefilestore - Default = False
# workspaceblobstore - Default = True
# Folder created!
# Saving files...
# "Datastore.upload" is deprecated after version 1.0.69. Please use "Dataset.File.upload_directory" to upload your files             from a local directory and create FileDataset in single method call. See Dataset API change notice at https://aka.ms/dataset-deprecation.
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data/1.csv
# Uploaded batch-data/1.csv, 1 files out of an estimated total of 100
# Uploading batch-data/10.csv
# Uploaded batch-data/10.csv, 2 files out of an estimated total of 100
# Uploading batch-data/100.csv
# Uploaded batch-data/100.csv, 3 files out of an estimated total of 100
# Uploading batch-data/11.csv
# Uploaded batch-data/11.csv, 4 files out of an estimated total of 100
# Uploading batch-data/12.csv
# Uploaded batch-data/12.csv, 5 files out of an estimated total of 100
# Uploading batch-data/13.csv
# Uploaded batch-data/13.csv, 6 files out of an estimated total of 100
# Uploading batch-data/14.csv
# Uploaded batch-data/14.csv, 7 files out of an estimated total of 100
# Uploading batch-data/15.csv
# Uploaded batch-data/15.csv, 8 files out of an estimated total of 100
# Uploading batch-data/16.csv
# Uploaded batch-data/16.csv, 9 files out of an estimated total of 100
# Uploading batch-data/17.csv
# Uploaded batch-data/17.csv, 10 files out of an estimated total of 100
# Uploading batch-data/18.csv
# Uploaded batch-data/18.csv, 11 files out of an estimated total of 100
# Uploading batch-data/19.csv
# Uploaded batch-data/19.csv, 12 files out of an estimated total of 100
# Uploading batch-data/2.csv
# Uploaded batch-data/2.csv, 13 files out of an estimated total of 100
# Uploading batch-data/20.csv
# Uploaded batch-data/20.csv, 14 files out of an estimated total of 100
# Uploading batch-data/21.csv
# Uploaded batch-data/21.csv, 15 files out of an estimated total of 100
# Uploading batch-data/22.csv
# Uploaded batch-data/22.csv, 16 files out of an estimated total of 100
# Uploading batch-data/23.csv
# Uploaded batch-data/23.csv, 17 files out of an estimated total of 100
# Uploading batch-data/24.csv
# Uploaded batch-data/24.csv, 18 files out of an estimated total of 100
# Uploading batch-data/25.csv
# Uploaded batch-data/25.csv, 19 files out of an estimated total of 100
# Uploading batch-data/26.csv
# Uploaded batch-data/26.csv, 20 files out of an estimated total of 100
# Uploading batch-data/27.csv
# Uploaded batch-data/27.csv, 21 files out of an estimated total of 100
# Uploading batch-data/28.csv
# Uploaded batch-data/28.csv, 22 files out of an estimated total of 100
# Uploading batch-data/29.csv
# Uploaded batch-data/29.csv, 23 files out of an estimated total of 100
# Uploading batch-data/3.csv
# Uploaded batch-data/3.csv, 24 files out of an estimated total of 100
# Uploading batch-data/30.csv
# Uploaded batch-data/30.csv, 25 files out of an estimated total of 100
# Uploading batch-data/31.csv
# Uploaded batch-data/31.csv, 26 files out of an estimated total of 100
# Uploading batch-data/32.csv
# Uploaded batch-data/32.csv, 27 files out of an estimated total of 100
# Uploading batch-data/33.csv
# Uploaded batch-data/33.csv, 28 files out of an estimated total of 100
# Uploading batch-data/34.csv
# Uploaded batch-data/34.csv, 29 files out of an estimated total of 100
# Uploading batch-data/35.csv
# Uploaded batch-data/35.csv, 30 files out of an estimated total of 100
# Uploading batch-data/36.csv
# Uploaded batch-data/36.csv, 31 files out of an estimated total of 100
# Uploading batch-data/37.csv
# Uploaded batch-data/37.csv, 32 files out of an estimated total of 100
# Uploading batch-data/38.csv
# Uploaded batch-data/38.csv, 33 files out of an estimated total of 100
# Uploading batch-data/39.csv
# Uploaded batch-data/39.csv, 34 files out of an estimated total of 100
# Uploading batch-data/4.csv
# Uploaded batch-data/4.csv, 35 files out of an estimated total of 100
# Uploading batch-data/40.csv
# Uploaded batch-data/40.csv, 36 files out of an estimated total of 100
# Uploading batch-data/41.csv
# Uploaded batch-data/41.csv, 37 files out of an estimated total of 100
# Uploading batch-data/42.csv
# Uploaded batch-data/42.csv, 38 files out of an estimated total of 100
# Uploading batch-data/43.csv
# Uploaded batch-data/43.csv, 39 files out of an estimated total of 100
# Uploading batch-data/44.csv
# Uploaded batch-data/44.csv, 40 files out of an estimated total of 100
# Uploading batch-data/47.csv
# Uploaded batch-data/47.csv, 41 files out of an estimated total of 100
# Uploading batch-data/45.csv
# Uploaded batch-data/45.csv, 42 files out of an estimated total of 100
# Uploading batch-data/46.csv
# Uploaded batch-data/46.csv, 43 files out of an estimated total of 100
# Uploading batch-data/48.csv
# Uploaded batch-data/48.csv, 44 files out of an estimated total of 100
# Uploading batch-data/49.csv
# Uploaded batch-data/49.csv, 45 files out of an estimated total of 100
# Uploading batch-data/5.csv
# Uploaded batch-data/5.csv, 46 files out of an estimated total of 100
# Uploading batch-data/50.csv
# Uploaded batch-data/50.csv, 47 files out of an estimated total of 100
# Uploading batch-data/51.csv
# Uploaded batch-data/51.csv, 48 files out of an estimated total of 100
# Uploading batch-data/52.csv
# Uploaded batch-data/52.csv, 49 files out of an estimated total of 100
# Uploading batch-data/53.csv
# Uploaded batch-data/53.csv, 50 files out of an estimated total of 100
# Uploading batch-data/54.csv
# Uploaded batch-data/54.csv, 51 files out of an estimated total of 100
# Uploading batch-data/55.csv
# Uploaded batch-data/55.csv, 52 files out of an estimated total of 100
# Uploading batch-data/56.csv
# Uploaded batch-data/56.csv, 53 files out of an estimated total of 100
# Uploading batch-data/57.csv
# Uploaded batch-data/57.csv, 54 files out of an estimated total of 100
# Uploading batch-data/58.csv
# Uploaded batch-data/58.csv, 55 files out of an estimated total of 100
# Uploading batch-data/59.csv
# Uploaded batch-data/59.csv, 56 files out of an estimated total of 100
# Uploading batch-data/6.csv
# Uploaded batch-data/6.csv, 57 files out of an estimated total of 100
# Uploading batch-data/60.csv
# Uploaded batch-data/60.csv, 58 files out of an estimated total of 100
# Uploading batch-data/61.csv
# Uploaded batch-data/61.csv, 59 files out of an estimated total of 100
# Uploading batch-data/62.csv
# Uploaded batch-data/62.csv, 60 files out of an estimated total of 100
# Uploading batch-data/63.csv
# Uploaded batch-data/63.csv, 61 files out of an estimated total of 100
# Uploading batch-data/64.csv
# Uploaded batch-data/64.csv, 62 files out of an estimated total of 100
# Uploading batch-data/65.csv
# Uploaded batch-data/65.csv, 63 files out of an estimated total of 100
# Uploading batch-data/66.csv
# Uploaded batch-data/66.csv, 64 files out of an estimated total of 100
# Uploading batch-data/67.csv
# Uploaded batch-data/67.csv, 65 files out of an estimated total of 100
# Uploading batch-data/68.csv
# Uploaded batch-data/68.csv, 66 files out of an estimated total of 100
# Uploading batch-data/69.csv
# Uploaded batch-data/69.csv, 67 files out of an estimated total of 100
# Uploading batch-data/7.csv
# Uploaded batch-data/7.csv, 68 files out of an estimated total of 100
# Uploading batch-data/70.csv
# Uploaded batch-data/70.csv, 69 files out of an estimated total of 100
# Uploading batch-data/71.csv
# Uploaded batch-data/71.csv, 70 files out of an estimated total of 100
# Uploading batch-data/72.csv
# Uploaded batch-data/72.csv, 71 files out of an estimated total of 100
# Uploading batch-data/73.csv
# Uploaded batch-data/73.csv, 72 files out of an estimated total of 100
# Uploading batch-data/74.csv
# Uploaded batch-data/74.csv, 73 files out of an estimated total of 100
# Uploading batch-data/75.csv
# Uploaded batch-data/75.csv, 74 files out of an estimated total of 100
# Uploading batch-data/76.csv
# Uploaded batch-data/76.csv, 75 files out of an estimated total of 100
# Uploading batch-data/77.csv
# Uploaded batch-data/77.csv, 76 files out of an estimated total of 100
# Uploading batch-data/78.csv
# Uploaded batch-data/78.csv, 77 files out of an estimated total of 100
# Uploading batch-data/79.csv
# Uploaded batch-data/79.csv, 78 files out of an estimated total of 100
# Uploading batch-data/8.csv
# Uploaded batch-data/8.csv, 79 files out of an estimated total of 100
# Uploading batch-data/80.csv
# Uploaded batch-data/80.csv, 80 files out of an estimated total of 100
# Uploading batch-data/81.csv
# Uploaded batch-data/81.csv, 81 files out of an estimated total of 100
# Uploading batch-data/82.csv
# Uploaded batch-data/82.csv, 82 files out of an estimated total of 100
# Uploading batch-data/83.csv
# Uploaded batch-data/83.csv, 83 files out of an estimated total of 100
# Uploading batch-data/84.csv
# Uploaded batch-data/84.csv, 84 files out of an estimated total of 100
# Uploading batch-data/85.csv
# Uploaded batch-data/85.csv, 85 files out of an estimated total of 100
# Uploading batch-data/86.csv
# Uploaded batch-data/86.csv, 86 files out of an estimated total of 100
# Uploading batch-data/87.csv
# Uploaded batch-data/87.csv, 87 files out of an estimated total of 100
# Uploading batch-data/88.csv
# Uploaded batch-data/88.csv, 88 files out of an estimated total of 100
# Uploading batch-data/89.csv
# Uploaded batch-data/89.csv, 89 files out of an estimated total of 100
# Uploading batch-data/9.csv
# Uploaded batch-data/9.csv, 90 files out of an estimated total of 100
# Uploading batch-data/90.csv
# Uploaded batch-data/90.csv, 91 files out of an estimated total of 100
# Uploading batch-data/91.csv
# Uploaded batch-data/91.csv, 92 files out of an estimated total of 100
# Uploading batch-data/92.csv
# Uploaded batch-data/92.csv, 93 files out of an estimated total of 100
# Uploading batch-data/93.csv
# Uploaded batch-data/93.csv, 94 files out of an estimated total of 100
# Uploading batch-data/94.csv
# Uploaded batch-data/94.csv, 95 files out of an estimated total of 100
# Uploading batch-data/95.csv
# Uploaded batch-data/95.csv, 96 files out of an estimated total of 100
# Uploading batch-data/96.csv
# Uploaded batch-data/96.csv, 97 files out of an estimated total of 100
# Uploading batch-data/97.csv
# Uploaded batch-data/97.csv, 98 files out of an estimated total of 100
# Uploading batch-data/98.csv
# Uploaded batch-data/98.csv, 99 files out of an estimated total of 100
# Uploading batch-data/99.csv
# Uploaded batch-data/99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create compute
#
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "my-compute-cluster"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# > **Note**: Compute instances and clusters are based on standard Azure virtual machine images. For this exercise, the *Standard_DS11_v2* image is recommended to achieve the optimal balance of cost and performance. If your subscription has a quota that does not include this image, choose an alternative image; but bear in mind that a larger image may incur higher cost and a smaller image may not be sufficient to complete the tasks. Alternatively, ask your Azure administrator to extend your quota.
#
# ## Create a pipeline for batch inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Writing batch_pipeline/batch_diabetes.py

# %% [markdown]
# The pipeline will need an environment in which to run, so we'll create a Conda specification that includes the packages that the code uses.

# %%
# %%writefile $experiment_folder/batch_environment.yml
# name: batch_environment
# dependencies:
# - python=3.6.2
# - scikit-learn
# - pip
# - pip:
#   - azureml-defaults
# Out:
# Writing batch_pipeline/batch_environment.yml

# %% [markdown]
# Next we'll define a run context that includes the Conda environment.

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

# Create an Environment for the experiment
batch_env = Environment.from_conda_specification("experiment_env", experiment_folder + "/batch_environment.yml")
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.data import OutputFileDatasetConfig

output_dir = OutputFileDatasetConfig(name='inferences')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [cd1d1bbe][9660a912-6221-48a2-b94c-ad76441feb18], (This step will run and generate new outputs)
# Submitted PipelineRun f3a50b5f-2647-4d39-85a4-92df915d70f2
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/f3a50b5f-2647-4d39-85a4-92df915d70f2?wsid=/subscriptions/376621af-6a06-4df6-b902-d25c6239f015/resourcegroups/learning/workspaces/mllearningworkspace&tid=16b3c013-d300-468d-ac64-7eda0820b6d3
# PipelineRunId: f3a50b5f-2647-4d39-85a4-92df915d70f2
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/f3a50b5f-2647-4d39-85a4-92df915d70f2?wsid=/subscriptions/376621af-6a06-4df6-b902-d25c6239f015/resourcegroups/learning/workspaces/mllearningworkspace&tid=16b3c013-d300-468d-ac64-7eda0820b6d3
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 0e8dcf51-832d-466c-85a3-2bcebd9df599
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/0e8dcf51-832d-466c-85a3-2bcebd9df599?wsid=/subscriptions/376621af-6a06-4df6-b902-d25c6239f015/resourcegroups/learning/workspaces/mllearningworkspace&tid=16b3c013-d300-468d-ac64-7eda0820b6d3
# StepRun( batch-score-diabetes ) Status: Queued
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2022/12/13 16:41:46 Downloading source code...
# 2022/12/13 16:41:47 Finished downloading source code
# 2022/12/13 16:41:47 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/12/13 16:41:48 Successfully set up Docker network: acb_default_network
# 2022/12/13 16:41:48 Setting up Docker configuration...
# 2022/12/13 16:41:48 Successfully set up Docker configuration
# 2022/12/13 16:41:48 Logging in to registry: mllearningcontainer.azurecr.io
# 2022/12/13 16:41:49 Successfully logged into mllearningcontainer.azurecr.io
# 2022/12/13 16:41:49 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/12/13 16:41:49 Scanning for dependencies...
# 2022/12/13 16:41:49 Successfully scanned dependencies
# 2022/12/13 16:41:49 Launching container with name: acb_step_0
# Sending build context to Docker daemon  71.68kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220708.v1@sha256:2a7a3804e0b071870e78304aa13dab15c2ece3120f781a99d52f24ff6b71dea6
# mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220708.v1@sha256:2a7a3804e0b071870e78304aa13dab15c2ece3120f781a99d52f24ff6b71dea6: Pulling from azureml/openmpi4.1.0-ubuntu20.04
# d7bfe07ed847: Already exists
# 1a9a51b4af0d: Pulling fs layer
# 9d74d44c539e: Pulling fs layer
# 829bf1798a9e: Pulling fs layer
# 5fe57cb5a06b: Pulling fs layer
# 0b73c9d3e4c7: Pulling fs layer
# df3a1ae83fc1: Pulling fs layer
# 622a938b5eec: Pulling fs layer
# 9d0e20c4f643: Pulling fs layer
# e63d29d12ed0: Pulling fs layer
# 5fe57cb5a06b: Waiting
# 0b73c9d3e4c7: Waiting
# df3a1ae83fc1: Waiting
# 622a938b5eec: Waiting
# 9d0e20c4f643: Waiting
# e63d29d12ed0: Waiting
# 829bf1798a9e: Verifying Checksum
# 829bf1798a9e: Download complete
# 9d74d44c539e: Verifying Checksum
# 9d74d44c539e: Download complete
# 5fe57cb5a06b: Verifying Checksum
# 5fe57cb5a06b: Download complete
# df3a1ae83fc1: Verifying Checksum
# df3a1ae83fc1: Download complete
# 1a9a51b4af0d: Verifying Checksum
# 1a9a51b4af0d: Download complete
# 622a938b5eec: Verifying Checksum
# 622a938b5eec: Download complete
# 0b73c9d3e4c7: Verifying Checksum
# 0b73c9d3e4c7: Download complete
# e63d29d12ed0: Verifying Checksum
# e63d29d12ed0: Download complete
# 9d0e20c4f643: Verifying Checksum
# 9d0e20c4f643: Download complete
# 1a9a51b4af0d: Pull complete
# 9d74d44c539e: Pull complete
# 829bf1798a9e: Pull complete
# 5fe57cb5a06b: Pull complete
# 0b73c9d3e4c7: Pull complete
# df3a1ae83fc1: Pull complete
# 622a938b5eec: Pull complete
# 9d0e20c4f643: Pull complete
# e63d29d12ed0: Pull complete
# Digest: sha256:2a7a3804e0b071870e78304aa13dab15c2ece3120f781a99d52f24ff6b71dea6
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220708.v1@sha256:2a7a3804e0b071870e78304aa13dab15c2ece3120f781a99d52f24ff6b71dea6
#  ---> a126cf3d80b0
# Step 2/21 : USER root
#  ---> Running in ec088231b4a3
# Removing intermediate container ec088231b4a3
#  ---> ff1d23ce9e1c
# Step 3/21 : RUN mkdir -p $HOME/.cache
# StepRun( batch-score-diabetes ) Status: Running
#  ---> Running in 19d8e2bf0607
# Removing intermediate container 19d8e2bf0607
#  ---> 2e14fa5cbfe9
# Step 4/21 : WORKDIR /
#  ---> Running in a40a63a2ceb0
# Removing intermediate container a40a63a2ceb0
#  ---> 6b2928a69b5c
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> b2a86b724c6b
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 5516551bc602
# Removing intermediate container 5516551bc602
#  ---> 2d26beb51c27
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> fb952c29e89e
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 05c418c1c84c
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# intel-openmp-2022.1. | 4.5 MB    |            |   0%
# intel-openmp-2022.1. | 4.5 MB    | ########## | 100%
# intel-openmp-2022.1. | 4.5 MB    | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | ###2       |  33%
# python-3.6.2         | 23.6 MB   | #######6   |  77%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# zlib-1.2.13          | 103 KB    |            |   0%
# zlib-1.2.13          | 103 KB    | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | ####2      |  43%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# ca-certificates-2022 | 124 KB    |            |   0%
# ca-certificates-2022 | 124 KB    | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# libgcc-ng-11.2.0     | 5.3 MB    |            |   0%
# libgcc-ng-11.2.0     | 5.3 MB    | ########## | 100%
# libgcc-ng-11.2.0     | 5.3 MB    | ########## | 100%
#
# tk-8.6.12            | 3.0 MB    |            |   0%
# tk-8.6.12            | 3.0 MB    | ########## | 100%
# tk-8.6.12            | 3.0 MB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# _openmp_mutex-5.1    | 21 KB     |            |   0%
# _openmp_mutex-5.1    | 21 KB     | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# wheel-0.37.1         | 33 KB     |            |   0%
# wheel-0.37.1         | 33 KB     | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# xz-5.2.8             | 429 KB    |            |   0%
# xz-5.2.8             | 429 KB    | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# libgomp-11.2.0       | 474 KB    |            |   0%
# libgomp-11.2.0       | 474 KB    | ########## | 100%
#
# setuptools-58.0.4    | 788 KB    |            |   0%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# libstdcxx-ng-11.2.0  | 4.7 MB    |            |   0%
# libstdcxx-ng-11.2.0  | 4.7 MB    | ########## | 100%
# libstdcxx-ng-11.2.0  | 4.7 MB    | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 3          |   3%
# mkl-2020.2           | 138.3 MB  | #          |  11%
# mkl-2020.2           | 138.3 MB  | #7         |  18%
# mkl-2020.2           | 138.3 MB  | ##4        |  24%
# mkl-2020.2           | 138.3 MB  | ###        |  30%
# mkl-2020.2           | 138.3 MB  | ###9       |  40%
# mkl-2020.2           | 138.3 MB  | ####7      |  47%
# mkl-2020.2           | 138.3 MB  | #####4     |  54%
# mkl-2020.2           | 138.3 MB  | ######4    |  64%
# mkl-2020.2           | 138.3 MB  | #######1   |  72%
# mkl-2020.2           | 138.3 MB  | #######8   |  79%
# mkl-2020.2           | 138.3 MB  | ########9  |  90%
# mkl-2020.2           | 138.3 MB  | #########8 |  98%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.aoau6p3l.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.48.0-py3-none-any.whl (2.0 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.48.0
#   Downloading azureml_dataset_runtime-1.48.0-py3-none-any.whl (2.2 kB)
# Collecting azureml-inference-server-http~=0.7.2
#   Downloading azureml_inference_server_http-0.7.7-py3-none-any.whl (56 kB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.47.0-py3-none-any.whl (2.0 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-core~=1.47.0
#   Downloading azureml_core-1.47.0-py3-none-any.whl (3.1 MB)
# Collecting azureml-dataset-runtime[fuse]~=1.47.0
#   Downloading azureml_dataset_runtime-1.47.0-py3-none-any.whl (2.2 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azure-mgmt-resource<22.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-21.1.0-py3-none-any.whl (1.8 MB)
# Collecting azure-mgmt-containerregistry<11,>=8.2.0
#   Downloading azure_mgmt_containerregistry-10.0.0-py3-none-any.whl (1.2 MB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting argcomplete<3
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# Collecting docker<7.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting azure-mgmt-storage<21.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-20.0.0-py3-none-any.whl (2.0 MB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting python-dateutil<3.0.0,>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Collecting azure-mgmt-authorization<3,>=0.40.0
#   Downloading azure_mgmt_authorization-2.0.0-py2.py3-none-any.whl (465 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.12.0-py2.py3-none-any.whl (213 kB)
# Collecting knack~=0.10.0
#   Downloading knack-0.10.1-py3-none-any.whl (61 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting azure-mgmt-keyvault<11.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-10.0.0-py3-none-any.whl (489 kB)
# Collecting pyopenssl<23.0.0
#   Downloading pyOpenSSL-22.1.0-py3-none-any.whl (57 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting pytz
#   Downloading pytz-2022.6-py2.py3-none-any.whl (498 kB)
# Collecting urllib3<2.0.0,>=1.23
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.20.0-py2.py3-none-any.whl (90 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting pkginfo
#   Downloading pkginfo-1.9.2-py3-none-any.whl (26 kB)
# Collecting packaging<22.0,>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting azure-core<2.0.0
#   Downloading azure_core-1.24.2-py3-none-any.whl (178 kB)
# Collecting jmespath<2.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.4.0-py3-none-any.whl (18 kB)
# Collecting msrest<=0.7.1,>=0.5.1
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<41
#   Downloading cryptography-38.0.4-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting importlib-metadata<5,>=0.23
#   Downloading importlib_metadata-4.8.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azure-core<2.0.0->azureml-core~=1.47.0->azureml-defaults->-r /azureml-environment-setup/condaenv.aoau6p3l.requirements.txt (line 1)) (1.16.0)
# Collecting typing-extensions>=4.0.1
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.47.0->azureml-defaults->-r /azureml-environment-setup/condaenv.aoau6p3l.requirements.txt (line 1)) (1.19.2)
# Collecting azureml-dataprep<4.6.0a,>=4.5.0a
#   Downloading azureml_dataprep-4.5.7-py3-none-any.whl (43.4 MB)
# Collecting pyarrow<=9.0.0,>=0.17.0
#   Downloading pyarrow-6.0.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.6 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting jsonschema
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting pyyaml<7.0.0,>=5.1.0
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
# Collecting azureml-dataprep-rslex~=2.11.0dev0
#   Downloading azureml_dataprep_rslex-2.11.4-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.3 MB)
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
# Collecting dotnetcore2<4.0.0,>=3.0.0
#   Downloading dotnetcore2-3.1.23-py3-none-manylinux1_x86_64.whl (31.1 MB)
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting flask-cors~=3.0.1
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting inference-schema~=1.4.0
#   Downloading inference_schema-1.4.2.1-py3-none-any.whl (21 kB)
# Collecting opencensus-ext-azure~=1.1.0
#   Downloading opencensus_ext_azure-1.1.7-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-inference-server-http~=0.7.2->azureml-defaults->-r /azureml-environment-setup/condaenv.aoau6p3l.requirements.txt (line 1)) (58.0.4)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (402 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.1-py3-none-any.whl (54 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Collecting Flask>=0.9
#   Downloading Flask-2.0.3-py3-none-any.whl (95 kB)
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting click>=7.1.2
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
# Collecting Jinja2>=3.0
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting tabulate
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Collecting pygments
#   Downloading Pygments-2.13.0-py3-none-any.whl (1.1 MB)
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.47.0->azureml-defaults->-r /azureml-environment-setup/condaenv.aoau6p3l.requirements.txt (line 1)) (2021.5.30)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting opencensus<1.0.0,>=0.11.0
#   Downloading opencensus-0.11.0-py2.py3-none-any.whl (128 kB)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
# Collecting opencensus-context>=0.1.3
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.8.2-py3-none-any.whl (114 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.56.3-py2.py3-none-any.whl (211 kB)
# Collecting protobuf<5.0.0dev,>=3.15.0
#   Downloading protobuf-3.19.6-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.15.0-py2.py3-none-any.whl (177 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.7-py3-none-any.whl (98 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting dataclasses
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.19-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (116 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.18.0-cp36-cp36m-manylinux1_x86_64.whl (117 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=18d4ebcca5f47ddb7ddc3b4abf8397bac762f6cfdad1ae09385a5a51efc8fdbd
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=99d732fdd28e315a06309e1ca5049fbac45aa3542fd6e2ecfaed99f81d8862c1
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=76174 sha256=c9f75f1f09463b7d837e7aa679bf7afdf07cc62be4a0fd27e669dbb753d604d6
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7681 sha256=20d43d8aab8c8efd352664447b6b772f9ab3db741e23141dea232e83e28625e9
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py fusepy wrapt contextvars
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, typing-extensions, requests, pyasn1, zipp, rsa, pyasn1-modules, protobuf, portalocker, oauthlib, msal, immutables, cachetools, requests-oauthlib, python-dateutil, pyrsistent, msal-extensions, MarkupSafe, isodate, importlib-metadata, googleapis-common-protos, google-auth, distro, dataclasses, contextvars, azure-core, attrs, Werkzeug, pyyaml, opencensus-context, msrest, jsonschema, Jinja2, itsdangerous, google-api-core, dotnetcore2, cloudpickle, click, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, websocket-client, tabulate, pytz, PySocks, pyparsing, pyopenssl, pynacl, pygments, pyarrow, psutil, opencensus, msrestazure, jmespath, jeepney, Flask, bcrypt, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, argcomplete, SecretStorage, pkginfo, pathspec, paramiko, packaging, opencensus-ext-azure, ndg-httpsclient, knack, jsonpickle, inference-schema, humanfriendly, gunicorn, fusepy, flask-cors, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, json-logging-py, configparser, azureml-inference-server-http, azureml-core, azureml-defaults
# Successfully installed Flask-2.0.3 Jinja2-3.0.3 MarkupSafe-2.0.1 PyJWT-2.4.0 PySocks-1.7.1 SecretStorage-3.3.3 Werkzeug-2.0.3 adal-1.2.7 argcomplete-2.0.0 attrs-22.1.0 azure-common-1.1.28 azure-core-1.24.2 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-2.0.0 azure-mgmt-containerregistry-10.0.0 azure-mgmt-core-1.3.2 azure-mgmt-keyvault-10.0.0 azure-mgmt-resource-21.1.0 azure-mgmt-storage-20.0.0 azureml-core-1.47.0 azureml-dataprep-4.5.7 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.11.4 azureml-dataset-runtime-1.47.0 azureml-defaults-1.47.0 azureml-inference-server-http-0.7.7 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-4.0.1 cachetools-4.2.4 cffi-1.15.1 charset-normalizer-2.0.12 click-8.0.4 cloudpickle-2.2.0 configparser-3.7.4 contextlib2-21.6.0 contextvars-2.4 cryptography-38.0.4 dataclasses-0.8 distro-1.8.0 docker-5.0.3 dotnetcore2-3.1.23 flask-cors-3.0.10 fusepy-3.0.1 google-api-core-2.8.2 google-auth-2.15.0 googleapis-common-protos-1.56.3 gunicorn-20.1.0 humanfriendly-10.0 idna-3.4 immutables-0.19 importlib-metadata-4.8.3 inference-schema-1.4.2.1 isodate-0.6.1 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.2.0 jsonschema-3.2.0 knack-0.10.1 msal-1.20.0 msal-extensions-0.3.1 msrest-0.7.1 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.2.2 opencensus-0.11.0 opencensus-context-0.1.3 opencensus-ext-azure-1.1.7 packaging-21.3 paramiko-2.12.0 pathspec-0.9.0 pkginfo-1.9.2 portalocker-2.6.0 protobuf-3.19.6 psutil-5.9.4 pyarrow-6.0.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.21 pygments-2.13.0 pynacl-1.5.0 pyopenssl-22.1.0 pyparsing-3.0.7 pyrsistent-0.18.0 python-dateutil-2.8.2 pytz-2022.6 pyyaml-6.0 requests-2.27.1 requests-oauthlib-1.3.1 rsa-4.9 tabulate-0.8.10 typing-extensions-4.1.1 urllib3-1.26.13 websocket-client-1.3.1 wrapt-1.12.1 zipp-3.6.0
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container 05c418c1c84c
#  ---> 75d87fba0395
# Step 9/21 : ENV PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin:$PATH
#  ---> Running in cc409869ea30
# Removing intermediate container cc409869ea30
#  ---> eaaba0d3a70f
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 3435d7d5ba54
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in dbfd381e7ec0
# Copying environment context
# Removing intermediate container dbfd381e7ec0
#  ---> 5e4ae6a3b877
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> a4d494a8a0d4
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in 7349dbd5c578
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 7349dbd5c578
#  ---> 92b8df45bd9c
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in 073256a34006
# Removing intermediate container 073256a34006
#  ---> 362b2ba5e466
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib:$LD_LIBRARY_PATH
#  ---> Running in d6b3180db362
# Removing intermediate container d6b3180db362
#  ---> 8523314b70b6
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_e220b045f6c3c3008b1a386af067185d CONDA_PREFIX=/azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in e34c94c2904e
# Removing intermediate container e34c94c2904e
#  ---> ada1166f4268
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 8fc26687880c
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 60bf523f9efe
# Removing intermediate container 60bf523f9efe
#  ---> dbe752624109
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in a37fd4a4be41
# Removing intermediate container a37fd4a4be41
#  ---> 2684a221c9ff
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 7b042ad39963
# Removing intermediate container 7b042ad39963
#  ---> d91bc6da52a7
# Step 21/21 : CMD ["bash"]
#  ---> Running in 551f7e1e472c
# Removing intermediate container 551f7e1e472c
#  ---> 87b70a762c33
# Successfully built 87b70a762c33
# Successfully tagged mllearningcontainer.azurecr.io/azureml/azureml_3d9573a5eb84459cf62cf1152318fbf6:latest
# Successfully tagged mllearningcontainer.azurecr.io/azureml/azureml_3d9573a5eb84459cf62cf1152318fbf6:1
# 2022/12/13 16:43:51 Successfully executed container: acb_step_0
# 2022/12/13 16:43:51 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/12/13 16:43:51 Pushing image: mllearningcontainer.azurecr.io/azureml/azureml_3d9573a5eb84459cf62cf1152318fbf6:1, attempt 1
# The push refers to repository [mllearningcontainer.azurecr.io/azureml/azureml_3d9573a5eb84459cf62cf1152318fbf6]
# 7ba80c5f2614: Preparing
# 8b03ef692ed0: Preparing
# 5584b102e55d: Preparing
# 38215ba630f6: Preparing
# 05a413182f81: Preparing
# a563a3dee940: Preparing
# 2137bf499185: Preparing
# 73e78a3d3237: Preparing
# 4f3df0525065: Preparing
# 3470b873397a: Preparing
# cc45347b4ace: Preparing
# 1b372d66233e: Preparing
# 07a28cde7d10: Preparing
# 30396212e2bd: Preparing
# e2efb02e0592: Preparing
# dafbdffeff20: Preparing
# 657ccef222ea: Preparing
# a2fbf4296693: Preparing
# 149bb2b607d0: Preparing
# af7ed92504ae: Preparing
# a563a3dee940: Waiting
# 2137bf499185: Waiting
# 73e78a3d3237: Waiting
# 4f3df0525065: Waiting
# 3470b873397a: Waiting
# 1b372d66233e: Waiting
# cc45347b4ace: Waiting
# 07a28cde7d10: Waiting
# a2fbf4296693: Waiting
# 30396212e2bd: Waiting
# e2efb02e0592: Waiting
# dafbdffeff20: Waiting
# 657ccef222ea: Waiting
# 149bb2b607d0: Waiting
# af7ed92504ae: Waiting
# 38215ba630f6: Pushed
# 05a413182f81: Pushed
# 8b03ef692ed0: Pushed
# 7ba80c5f2614: Pushed
# 2137bf499185: Pushed
# 73e78a3d3237: Pushed
# 5584b102e55d: Pushed
# 4f3df0525065: Pushed
# 3470b873397a: Pushed
# cc45347b4ace: Pushed
# 1b372d66233e: Pushed
# 07a28cde7d10: Pushed
# dafbdffeff20: Pushed
# 30396212e2bd: Pushed
# 657ccef222ea: Pushed
# a2fbf4296693: Pushed
# e2efb02e0592: Pushed
# af7ed92504ae: Pushed
#
# 149bb2b607d0: Pushed
# a563a3dee940: Pushed
# 1: digest: sha256:ec6c231c9b2b60b7ed62a86ef09839b821f4f5d6e5443b8c22446f954c967a7d size: 4513
# 2022/12/13 16:45:21 Successfully pushed image: mllearningcontainer.azurecr.io/azureml/azureml_3d9573a5eb84459cf62cf1152318fbf6:1
# 2022/12/13 16:45:21 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/12/13 16:45:21 Pushing image: mllearningcontainer.azurecr.io/azureml/azureml_3d9573a5eb84459cf62cf1152318fbf6:latest, attempt 1
# The push refers to repository [mllearningcontainer.azurecr.io/azureml/azureml_3d9573a5eb84459cf62cf1152318fbf6]
# 7ba80c5f2614: Preparing
# 8b03ef692ed0: Preparing
# 5584b102e55d: Preparing
# 38215ba630f6: Preparing
# 05a413182f81: Preparing
# a563a3dee940: Preparing
# 2137bf499185: Preparing
# 73e78a3d3237: Preparing
# 4f3df0525065: Preparing
# 3470b873397a: Preparing
# cc45347b4ace: Preparing
# 1b372d66233e: Preparing
# 07a28cde7d10: Preparing
# 30396212e2bd: Preparing
# e2efb02e0592: Preparing
# dafbdffeff20: Preparing
# 657ccef222ea: Preparing
# a2fbf4296693: Preparing
# 149bb2b607d0: Preparing
# af7ed92504ae: Preparing
# a563a3dee940: Waiting
# 2137bf499185: Waiting
# 73e78a3d3237: Waiting
# 4f3df0525065: Waiting
# 3470b873397a: Waiting
# cc45347b4ace: Waiting
# 1b372d66233e: Waiting
# 07a28cde7d10: Waiting
# a2fbf4296693: Waiting
# 30396212e2bd: Waiting
# e2efb02e0592: Waiting
# 149bb2b607d0: Waiting
# af7ed92504ae: Waiting
# dafbdffeff20: Waiting
# 657ccef222ea: Waiting
# 7ba80c5f2614: Layer already exists
# 05a413182f81: Layer already exists
# 5584b102e55d: Layer already exists
# 38215ba630f6: Layer already exists
# 8b03ef692ed0: Layer already exists
# a563a3dee940: Layer already exists
# 2137bf499185: Layer already exists
# 73e78a3d3237: Layer already exists
# 3470b873397a: Layer already exists
# 4f3df0525065: Layer already exists
# 1b372d66233e: Layer already exists
# cc45347b4ace: Layer already exists
# 07a28cde7d10: Layer already exists
# e2efb02e0592: Layer already exists
# 30396212e2bd: Layer already exists
# 657ccef222ea: Layer already exists
# dafbdffeff20: Layer already exists
# 149bb2b607d0: Layer already exists
# a2fbf4296693: Layer already exists
# af7ed92504ae: Layer already exists
# latest: digest: sha256:ec6c231c9b2b60b7ed62a86ef09839b821f4f5d6e5443b8c22446f954c967a7d size: 4513
# 2022/12/13 16:45:22 Successfully pushed image: mllearningcontainer.azurecr.io/azureml/azureml_3d9573a5eb84459cf62cf1152318fbf6:latest
# 2022/12/13 16:45:22 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 122.373660)
# 2022/12/13 16:45:22 Populating digests for step ID: acb_step_0...
# 2022/12/13 16:45:24 Successfully populated digests for step ID: acb_step_0
# 2022/12/13 16:45:24 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 89.294832)
# 2022/12/13 16:45:24 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.800578)
# 2022/12/13 16:45:24 The following dependencies were found:
# 2022/12/13 16:45:24
# - image:
#     registry: mllearningcontainer.azurecr.io
#     repository: azureml/azureml_3d9573a5eb84459cf62cf1152318fbf6
#     tag: latest
#     digest: sha256:ec6c231c9b2b60b7ed62a86ef09839b821f4f5d6e5443b8c22446f954c967a7d
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220708.v1
#     digest: sha256:2a7a3804e0b071870e78304aa13dab15c2ece3120f781a99d52f24ff6b71dea6
#   git: {}
# - image:
#     registry: mllearningcontainer.azurecr.io
#     repository: azureml/azureml_3d9573a5eb84459cf62cf1152318fbf6
#     tag: "1"
#     digest: sha256:ec6c231c9b2b60b7ed62a86ef09839b821f4f5d6e5443b8c22446f954c967a7d
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220708.v1
#     digest: sha256:2a7a3804e0b071870e78304aa13dab15c2ece3120f781a99d52f24ff6b71dea6
#   git: {}
#
# Run ID: cb2 was successful after 3m39s
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '0e8dcf51-832d-466c-85a3-2bcebd9df599', 'target': 'my-compute-cluster', 'status': 'Completed', 'startTimeUtc': '2022-12-13T16:58:01.865871Z', 'endTimeUtc': '2022-12-13T17:00:02.696778Z', 'services': {}, 'properties': {'ContentSnapshotId': 'ffa535f2-e066-4882-a6c8-10cc376b7f16', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '9660a912-6221-48a2-b94c-ad76441feb18', 'azureml.moduleName': 'batch-score-diabetes', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'cd1d1bbe', 'azureml.pipelinerunid': 'f3a50b5f-2647-4d39-85a4-92df915d70f2', 'azureml.pipeline': 'f3a50b5f-2647-4d39-85a4-92df915d70f2', 'azureml.pipelineComponent': 'masterescloud', 'azureml.parallelrunstep': 'true', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '6c308bb9-ae1a-47f1-90c2-59092ad69db3'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [{'identifier': {'savedId': 'bd0ed93a-f74a-47e2-a92f-4dd08f91c24a'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'inferences'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/0e8dcf51-832d-466c-85a3-2bcebd9df599/inferences/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "bd0ed93a-f74a-47e2-a92f-4dd08f91c24a",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='mllearningworkspace', subscription_id='376621af-6a06-4df6-b902-d25c6239f015', resource_group='learning')"
#   }
# }}], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.44.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'my-compute-cluster', 'dataReferences': {}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '6c308bb9-ae1a-47f1-90c2-59092ad69db3', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'inferences': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'properties': {'azureml.pipelineRunId': 'f3a50b5f-2647-4d39-85a4-92df915d70f2', 'azureml.pipelineRun.moduleNodeId': 'cd1d1bbe', 'azureml.pipelineRun.outputPortName': 'inferences'}, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': 'Autosave_2022-12-13T16:41:41Z_769ee2c0', 'assetId': 'azureml://locations/westeurope/workspaces/8c877630-3281-4ea1-89cf-f8f8040c7370/environments/experiment_env/versions/Autosave_2022-12-13T16:41:41Z_769ee2c0', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'batch_environment', 'dependencies': ['python=3.6.2', 'scikit-learn', 'pip', {'pip': ['azureml-defaults']}]}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220708.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'argumen ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'f3a50b5f-2647-4d39-85a4-92df915d70f2', 'status': 'Completed', 'startTimeUtc': '2022-12-13T16:40:48.482824Z', 'endTimeUtc': '2022-12-13T17:00:04.147639Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.continue_on_failed_optional_input': 'True', 'azureml.pipelineComponent': 'pipelinerun', 'azureml.pipelines.stages': '{"Initialization":null,"Execution":{"StartTime":"2022-12-13T16:40:48.921253+00:00","EndTime":"2022-12-13T17:00:04.0515809+00:00","Status":"Finished"}}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mllearningwork3345488027.blob.core.windows.net/azureml/ExperimentRun/dcid.f3a50b5f-2647-4d39-85a4-92df915d70f2/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=SN0wyTDu5e57TjzAH2Oox15Wo0b8jcXSIoS76aXrT2w%3D&skoid=530a969d-1f1a-4d2a-9866-6f18d23e261b&sktid=16b3c013-d300-468d-ac64-7eda0820b6d3&skt=2022-12-13T11%3A44%3A04Z&ske=2022-12-14T19%3A54%3A04Z&sks=b&skv=2019-07-07&st=2022-12-13T16%3A50%3A06Z&se=2022-12-14T01%3A00%3A06Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mllearningwork3345488027.blob.core.windows.net/azureml/ExperimentRun/dcid.f3a50b5f-2647-4d39-85a4-92df915d70f2/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=L8XvTX6GzY5%2BnoMkfUKCa9NGw%2B0iElteoR0gXa00MeA%3D&skoid=530a969d-1f1a-4d2a-9866-6f18d23e261b&sktid=16b3c013-d300-468d-ac64-7eda0820b6d3&skt=2022-12-13T11%3A44%3A04Z&ske=2022-12-14T19%3A54%3A04Z&sks=b&skv=2019-07-07&st=2022-12-13T16%3A50%3A06Z&se=2022-12-14T01%3A00%3A06Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mllearningwork3345488027.blob.core.windows.net/azureml/ExperimentRun/dcid.f3a50b5f-2647-4d39-85a4-92df915d70f2/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=bK9wM%2B8TKfm6KztuzU37yPMfJLs%2F36Bxb36Z7ycfhtw%3D&skoid=530a969d-1f1a-4d2a-9866-6f18d23e261b&sktid=16b3c013-d300-468d-ac64-7eda0820b6d3&skt=2022-12-13T11%3A44%3A04Z&ske=2022-12-14T19%3A54%3A04Z&sks=b&skv=2019-07-07&st=2022-12-13T16%3A50%3A06Z&se=2022-12-14T01%3A00%3A06Z&sp=r'}, 'submittedBy': 'Carlo Binda'}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
